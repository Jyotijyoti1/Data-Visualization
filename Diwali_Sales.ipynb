# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Diwali Sales Data.csv",encoding= 'unicode_escape')

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.head(10)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
# 5  1000588       Joni  P00057942      M     26-35   28               1
# 6  1001132       Balk  P00018042      F     18-25   25               1
# 7  1002092   Shivangi  P00273442      F       55+   61               0
# 8  1003224     Kushal  P00205642      M     26-35   35               0
# 9  1003650      Ginny  P00031142      F     26-35   26               1
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
df.tail(10)
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 11241  1003032     Matthias  P00058042      F     26-35   33               0
# 11242  1004344   Hildebrand  P00185442      F     26-35   27               1
# 11243  1005446      Sheetal  P00297742      M     51-55   53               0
# 11244  1005446      Sheetal  P00297742      M     51-55   53               0
# 11245  1004140    Bertelson  P00057442      F     26-35   31               1
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
#                 State      Zone   Occupation Product_Category  Orders  Amount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
df.drop(["unnamed1"],axis= 1,inplace=True)

# %%
df.drop(["Status"],axis=1,inplace= True)

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.dropna()
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.dropna(thresh = 10)
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.isna().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df["Amount"].isna().value_counts()
# Out:
# False    11239
# True        12
# Name: Amount, dtype: int64

# %%
# drop null values
df.dropna(inplace=True)

# %%
df["Amount"].isna().sum()
# Out:
# 0

# %%
df["Amount"] = df["Amount"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11239 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11239 non-null  int64
#  1   Cust_name         11239 non-null  object
#  2   Product_ID        11239 non-null  object
#  3   Gender            11239 non-null  object
#  4   Age Group         11239 non-null  object
#  5   Age               11239 non-null  int64
#  6   Marital_Status    11239 non-null  int64
#  7   State             11239 non-null  object
#  8   Zone              11239 non-null  object
#  9   Occupation        11239 non-null  object
#  10  Product_Category  11239 non-null  object
#  11  Orders            11239 non-null  int64
#  12  Amount            11239 non-null  int32
# dtypes: int32(1), int64(4), object(8)
# memory usage: 1.2+ MB

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
df["User_ID"]
# Out:
# 0        1002903
# 1        1000732
# 2        1001990
# 3        1001425
# 4        1000588
#           ...
# 11246    1000695
# 11247    1004089
# 11248    1001209
# 11249    1004023
# 11250    1002744
# Name: User_ID, Length: 11239, dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    11231
# True         8
# dtype: int64

# %%
df[df["User_ID"].duplicated()]
# Out:
#        User_ID     Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 5      1000588          Joni  P00057942      M     26-35   28               1
# 19     1001883       Praneet  P00029842      M     51-55   54               1
# 102    1004957    Inderpreet  P00163442      F     26-35   34               1
# 133    1003311         Neola  P00228142      F     26-35   30               1
# 139    1000838  Divyeshkumar  P00363542      M     51-55   53               1
# ...        ...           ...        ...    ...       ...  ...             ...
# 11246  1000695       Manning  P00296942      M     18-25   19               1
# 11247  1004089   Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209         Oshin  P00201342      F     36-45   40               0
# 11249  1004023        Noonan  P00059442      M     36-45   37               0
# 11250  1002744       Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df[df[["User_ID","Cust_name","Product_ID"]].duplicated()]
# Out:
#        User_ID     Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 5      1000588          Joni  P00057942      M     26-35   28               1
# 19     1001883       Praneet  P00029842      M     51-55   54               1
# 139    1000838  Divyeshkumar  P00363542      M     51-55   53               1
# 515    1005458        Akshat  P00151742      M     18-25   23               0
# 524    1001150         Becky  P00228142      M     26-35   29               0
# ...        ...           ...        ...    ...       ...  ...             ...
# 11024  1003770       Anthony  P00178742      M     36-45   40               0
# 11076  1003675       Hawkins  P00228442      M     36-45   43               1
# 11099  1001865          Cyra  P00268542      M     18-25   22               1
# 11135  1005972         Harms  P00315742      M     26-35   29               0
# 11244  1005446       Sheetal  P00297742      M     51-55   53               0
#
# ...

# %%
df["State"].unique()
# Out:
# array(['Maharashtra', 'Andhra\xa0Pradesh', 'Uttar Pradesh', 'Karnataka',
#        'Gujarat', 'Himachal Pradesh', 'Delhi', 'Jharkhand', 'Kerala',
#        'Haryana', 'Madhya Pradesh', 'Bihar', 'Rajasthan', 'Uttarakhand',
#        'Telangana', 'Punjab'], dtype=object)

# %%
df["Product_Category"].unique()
# Out:
# array(['Auto', 'Hand & Power Tools', 'Stationery', 'Tupperware',
#        'Footwear & Shoes', 'Furniture', 'Food', 'Games & Toys',
#        'Sports Products', 'Books', 'Electronics & Gadgets', 'Decor',
#        'Clothing & Apparel', 'Beauty', 'Household items', 'Pet Care',
#        'Veterinary', 'Office'], dtype=object)

# %%
# find out user_id, name, gender, occupation, product, amount

# %%
# sns.(data= df,"State",y="Marital_Status",kind= "box", hue="State",col="Gender")

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
df[["Age","Orders","Amount"]].describe()
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.410357      2.489634   9453.610553
# std       12.753866      1.114967   5222.355168
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %%
# Data Analysis(Gender)

# %%
sns.countplot(data=df, x= 'Gender')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data=df,x="Marital_Status",hue="Gender")
# Out:
# <AxesSubplot:xlabel='Marital_Status', ylabel='count'>

# %%
data = df.groupby(["Gender"],as_index= False)["Amount"].sum()

# %%
sns.barplot(x="Gender",y="Amount",data=data)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Amount'>

# %%
df["State"].value_counts().idxmax()
# Out:
# 'Uttar Pradesh'

# %%
# Uttar Pradesh is the state where the products has been sold the most

# %%
# find the gender and product which has been sold the most

# %%
df.groupby(["Gender","Product_Category"])["Product_Category"].count().idxmax()
# Out:
# ('F', 'Clothing & Apparel')

# %%
plt.figure(figsize=(25,10))
sns.countplot(data= df, x = "Product_Category",hue="Gender")
# Out:
# <AxesSubplot:xlabel='Product_Category', ylabel='count'>

# %%
df["Gender"].value_counts()
# Out:
# F    7832
# M    3407
# Name: Gender, dtype: int64

# %%
df["Amount"].sum()
# Out:
# 106249129

# %%
df["Age Group"]
# Out:
# 0        26-35
# 1        26-35
# 2        26-35
# 3         0-17
# 4        26-35
#          ...
# 11246    18-25
# 11247    26-35
# 11248    36-45
# 11249    36-45
# 11250    18-25
# Name: Age Group, Length: 11239, dtype: object

# %%
df.groupby("Age Group")["Amount"].sum()
# Out:
# Age Group
# 0-17      2699653
# 18-25    17240732
# 26-35    42613442
# 36-45    22144994
# 46-50     9207844
# 51-55     8261477
# 55+       4080987
# Name: Amount, dtype: int32

# %%
df.groupby("Orders")["State"].max()
# Out:
# Orders
# 1    Uttarakhand
# 2    Uttarakhand
# 3    Uttarakhand
# 4    Uttarakhand
# Name: State, dtype: object

# %%
df.groupby("Age Group")["Amount"].sum()
# Out:
# Age Group
# 0-17      2699653
# 18-25    17240732
# 26-35    42613442
# 36-45    22144994
# 46-50     9207844
# 51-55     8261477
# 55+       4080987
# Name: Amount, dtype: int32

# %%
df["Amount"].nlargest(10)
# Out:
# 0     23952
# 1     23934
# 2     23924
# 3     23912
# 4     23877
# 5     23877
# 6     23841
# 8     23809
# 9     23799
# 10    23770
# Name: Amount, dtype: int32

# %%
sns.histplot(data=df, x= "Amount",hue="Age Group")
# Out:
# <AxesSubplot:xlabel='Amount', ylabel='Count'>

# %%
# Conclusion: Age group 26-35 has spend alot
